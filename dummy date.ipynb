# %% [markdown]
# # ダミーデータの作成
# ## 【問題1】乱数の作成

# %%
import numpy as np
ave = (-3, 0)
cov = [[1.0, 0.8], [0.8, 1.0]]
n_sample = 500

date0 = np.random.multivariate_normal(ave, cov, n_sample)
print(date0.shape)


#シード値
np.random.seed(0)
print(date0)
# Out:
# (500, 2)
# [[-4.80006782e+00 -1.54698618e+00]
#  [-4.63714503e+00 -2.19879728e-01]
#  [-4.46267867e+00 -2.08076347e+00]
#  [-3.85346966e+00 -9.49196365e-01]
#  [-3.03192065e+00  2.27764648e-01]
#  [-3.59653339e+00  3.23229932e-01]
#  [-3.76046080e+00 -6.83506760e-01]
#  [-3.52660272e+00 -3.15568548e-01]
#  [-4.35253112e+00 -1.48228460e+00]
#  [-3.02691331e+00 -5.67090887e-01]
#  [-7.84713550e-01  2.62867115e+00]
#  [-3.58538300e+00 -1.05476937e+00]
#  [-4.69336749e+00 -2.61318911e+00]
#  [-2.98421761e+00 -1.02603072e-01]
#  [-4.91877408e+00 -9.89469999e-01]
#  [-3.26658152e+00 -2.74105461e-02]
#  [-1.53138965e+00  2.15844669e-01]
#  [-2.71938344e+00  3.79500330e-01]
#  [-4.54738211e+00 -7.86930327e-01]
#  [-2.53695299e+00  2.71853959e-01]
#  [-1.55620621e+00  5.45695585e-01]
#  [-1.99817931e+00  2.23559938e+00]
#  [-2.37797023e+00  3.44967255e-01]
#  [-2.05735800e+00  1.43437007e+00]
#  [-1.40164768e+00  1.46380355e+00]
#  [-2.27283514e+00  9.71863483e-01]
# ...

# %% [markdown]
# ## 【問題2】散布図による可視化
# 問題1で作成したデータ点を散布図により可視化してください。
#
#
# 散布図はmatplotlibのplt.scatter()を使うことで描けます。

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.xlabel("x1")
plt.ylabel("x2")
plt.title("scatter")
plt.scatter(date0[:,0], date0[:,1])
plt.show()

# %% [markdown]
# ## 【問題3】ヒストグラムによる可視化
# 問題1で作成したデータをヒストグラムにより可視化してください。
#
#
# ヒストグラムはplt.hist()を使うことで描けます。
#
#
# matplotlib.pyplot.hist — Matplotlib 3.1.1 documentation
#
#
# 各次元ごとに作成し、2つのヒストグラムとしてください。
#
#
# それぞれのヒストグラムの横軸の範囲はplt.xlim()を用いて揃えるようにしてください。

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
#plt.figure(figsize=(6, 4))
plt.hist(date0[: ,0],bins=50)
plt.xlabel("x1")
plt.ylabel("frequency")
plt.title("histogram of x1")
plt.xlim(-5.5, 2.5)
plt.ylim(0, 30)
plt.show()

#plt.figure(figsize=(6, 4))
plt.hist(date0[: ,1],bins=50)
plt.xlabel("x2")
plt.ylabel("frequency")
plt.title("histogram of x2")
plt.xlim(-5.5, 2.5)
plt.ylim(0, 32)
plt.show()

# %% [markdown]
# ## 【問題4】データの追加
#
# たに平均が(0, -3)、共分散行列が以下で表される2次元正規分布による乱数を500個作成してください。
#
#
# $$\begin{bmatrix}
# 1.0 & 0.8 \\ 0.8 & 1.0
# \end{bmatrix}$$
#
# そして、問題1、4それぞれのデータをひとつの散布図として可視化してください。凡例として問題1のものは0、問題4のものは1を表示してください。

# %%
import numpy as np

ave = (0, -3)
cov = [[1.0, 0.8], [0.8, 1.0]]
n_sample = 500

date1 = np.random.multivariate_normal(ave, cov, n_sample)
print(date1.shape)

#シード値
np.random.seed(0)
print(date2)
# Out:
# (500, 2)
# [[-1.80006782e+00 -4.54698618e+00]
#  [-1.63714503e+00 -3.21987973e+00]
#  [-1.46267867e+00 -5.08076347e+00]
#  [-8.53469662e-01 -3.94919637e+00]
#  [-3.19206463e-02 -2.77223535e+00]
#  [-5.96533392e-01 -2.67677007e+00]
#  [-7.60460798e-01 -3.68350676e+00]
#  [-5.26602723e-01 -3.31556855e+00]
#  [-1.35253112e+00 -4.48228460e+00]
#  [-2.69133121e-02 -3.56709089e+00]
#  [ 2.21528645e+00 -3.71328853e-01]
#  [-5.85382998e-01 -4.05476937e+00]
#  [-1.69336749e+00 -5.61318911e+00]
#  [ 1.57823896e-02 -3.10260307e+00]
#  [-1.91877408e+00 -3.98947000e+00]
#  [-2.66581524e-01 -3.02741055e+00]
#  [ 1.46861035e+00 -2.78415533e+00]
#  [ 2.80616560e-01 -2.62049967e+00]
#  [-1.54738211e+00 -3.78693033e+00]
#  [ 4.63047006e-01 -2.72814604e+00]
#  [ 1.44379379e+00 -2.45430441e+00]
#  [ 1.00182069e+00 -7.64400623e-01]
#  [ 6.22029770e-01 -2.65503275e+00]
#  [ 9.42641996e-01 -1.56562993e+00]
#  [ 1.59835232e+00 -1.53619645e+00]
#  [ 7.27164858e-01 -2.02813652e+00]
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

ave0 = (-3, 0) #1問目
ave1 = (0, -3) #4問目 
cov = [[1.0, 0.8], [0.8, 1.0]]
n_sample0 = 500 #1
n_sample1 = 500

date0 = np.random.multivariate_normal(ave0, cov, n_sample0)
date1 = np.random.multivariate_normal(ave1, cov, n_sample1)
np.random.seed(0)

plt.xlabel("x1")
plt.ylabel("x2")
plt.title("scatter")
plt.scatter(date0[:,0], date0[:,1], label=0)
plt.scatter(date1[:,0], date1[:,1], label=1)
plt.legend()
plt.show()

# %% [markdown]
# ## 【問題5】データの結合
# データはまとめておいた方が後々扱いやすいです。問題1、4で作成したndarrayを 結合 し、(1000, 2)のndarrayとしてください。結合はnp.concatenate()やnp.vstack()を使うことで行えます。

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

ave0 = (-3, 0) #1問目
ave1 = (0, -3) #4問目 
cov = [[1.0, 0.8], [0.8, 1.0]]
n_sample0 = 500 #1問目
n_sample1 = 500 #4問目

date0 = np.random.multivariate_normal(ave0, cov, n_sample0)
date1 = np.random.multivariate_normal(ave1, cov, n_sample1)
np.random.seed(0)

join_0 = np.random.multivariate_normal(ave0, cov, n_sample0)
join_1 = np.random.multivariate_normal(ave1, cov, n_sample1)

join_mix = np.concatenate([join_0, join_1])
print(join_mix.shape)
print(join_mix)
# Out:
# (1000, 2)
# [[-4.80006782 -1.54698618]
#  [-4.63714503 -0.21987973]
#  [-4.46267867 -2.08076347]
#  ...
#  [-0.2185878  -3.15676476]
#  [-1.37970304 -4.27950068]
#  [ 1.49786804 -2.33126243]]

# %% [markdown]
# ## 【問題6】ラベル付け
# ひとまとめになった1000個のデータそれぞれに対して、問題1、4どちらで作成したものなのかを示す ラベル 付けを行ってください。問題1のものには0、問題4のものには1を対応させます。
#
#
# 0と1を含むラベルの列を新たに追加し、(1000, 3)のndarrayを作成してください。
#
#
# 機械学習に使用するデータセットはこのような形になっていることが多いです。
#
#
# 《作成例》
#
#
# データが3個+3個の場合は以下のような(6, 3)のndarrayになります。

# %%
#問題１のラベル付け :0
label_0 = np.insert(join_0, 2, 0, axis=1)
print("問題１の配列数の確認:{}".format(label_0.shape))
print(label_0)
print()

#問題４のラベル付け :1
label_1 = np.insert(join_1, 2, 1, axis=1)
print("問題4の配列数の確認:{}".format(label_1.shape))
print(label_1)


#問題1と4の複合ラベル付け 
label_mix = np.concatenate([label_0, label_1])

print("問題1と4の配列数の確認:{}".format(label_mix.shape))
print(label_mix)
# Out:
# 問題１の配列数の確認:(500, 3)
# [[-4.80006782 -1.54698618  0.        ]
#  [-4.63714503 -0.21987973  0.        ]
#  [-4.46267867 -2.08076347  0.        ]
#  ...
#  [-3.40484501 -0.14372258  0.        ]
#  [-2.8415685   0.21800394  0.        ]
#  [-1.79803505  0.97547372  0.        ]]
#
# 問題4の配列数の確認:(500, 3)
# [[-0.80965753 -3.24520748  1.        ]
#  [ 0.36752954 -2.5662435   1.        ]
#  [-0.28006393 -3.15263683  1.        ]
#  ...
#  [-0.2185878  -3.15676476  1.        ]
#  [-1.37970304 -4.27950068  1.        ]
#  [ 1.49786804 -2.33126243  1.        ]]
# 問題1と4の配列数の確認:(1000, 3)
# [[-4.80006782 -1.54698618  0.        ]
#  [-4.63714503 -0.21987973  0.        ]
#  [-4.46267867 -2.08076347  0.        ]
#  ...
#  [-0.2185878  -3.15676476  1.        ]
#  [-1.37970304 -4.27950068  1.        ]
#  [ 1.49786804 -2.33126243  1.        ]]
