# %% [markdown]
# # Sprint7 クラスタリング

# %% [markdown]
# # ライブラリのimport

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA

# %% [markdown]
# # スクラッチクラスの実装

# %%
class ScratchKMeans():
    """KMeansクラスタリングのスクラッチ
    """
    def __init__(self, n_clusters=2,n_init=20,n_iter=100,verbose=False):
        """
        Scratch implementation of K-means

        Parameters
        ----------
        n_clusters : クラスタ数
        n_init : 何回初期化するか
        max_iter : 各初期化毎に何回学習させるか
        verbose : 学習状況を出力するか否か
        """
        self.n_clusters = n_clusters
        self.n_init = n_init
        self.n_iter = n_iter
        self.verbose = verbose
        # SSE（誤差）を小さくする方向に学習（更新）させていくため、初期値は大きいものを用意しておく
        self.best_sse = 10**20
        
    def _update_myu(self,X):
        """中心点の更新
        Parameters
        ----------
        X : 説明変数
        """
        self.pre_myu = self.myu
        # クラスタ数でループ
        for j in range(self.n_clusters):
            # ループ中のクラスタに該当する説明変数の値の平均値を新しい中心点とする
            xxxxxxxxxxxxxxxxxxxxxxxxxxxxx
        
    def _update_cluster(self,X):
        """クラスタの更新
        Parameters
        ----------
        X : 説明変数
        """
        # データ数でループ
        for i in range(len(X)):
            # 比較のための初期値
            dist_m = 10**20
            # クラスタ数でループ
            for j in range(self.n_clusters):
                # 該当クラスタの中心点との距離を計算
                xxxxxxxxxxxxxxxxxxxxxxxxxxxxx
                # 前回保存した（あるいは初期値）より距離が小さければ、そちらのクラスタを採用
                if dist < dist_m:
                    dist_m = dist
                    X[i,-1] = j
                    
    def calc_sse(self,X):
        """SSEの計算
        Parameters
        ----------
        X : 説明変数
        """
        # SSEの計算
        sse = 0
        # データ数でループ
        for i in range(len(X)):
            # クラスタ数でループ
            for j in range(self.n_clusters):
                # 末尾のクラスタを判定し、該当クラスタならsseに加算
                if j == X[i,-1]:
                    # ベクトルの距離（ノルム）計算＊末尾のクラスタを除いた数値を使用している点に注意
                    xxxxxxxxxxxxxxxxxxxxxxxxxxxxx
        # sseが改善していれば、更新
        if self.best_sse > sse:
            self.best_sse = sse
            self.record_myu = self.myu
            self.record_cluster = self.n_clusters
        
    def fit(self, X):
        """学習
        Parameters
        ----------
        X : 説明変数
        """
        # 初期化回数分ループ
        for i in range(self.n_init):
            
            # データXからクラスタ数分の初期値をランダムにとってくる(各クラスタの初期の中心点)
            self.myu = xxxxxxxxxxxxxxxxxxxxxxxxxxxxx
        
            # Xベクトルにクラスタ列を追加（クラスタは0で初期化）
            cluster = np.zeros(len(X))
            X_cluster = np.concatenate([X,cluster.reshape(-1,1)],axis=1)
            
            # 最大学習回数分ループ
            for j in range(self.n_iter):
                # SSEを更新
                self.calc_sse(X_cluster)

                # クラスタ更新
                self._update_cluster(X_cluster)
                
                # クラスタの中心点の更新
                self._update_myu(X_cluster)
                
                # 学習状況の出力（グラフ）
                if self.verbose:
                    print("初期化：%s　学習回数：%s　最善のSSE：%s"%(i,j,self.best_sse))
                
            
    def predict(self, X):
        """予測
        Parameters
        ----------
        X : 説明変数
        """
        # 予測値の初期化
        y_pred = np.zeros(len(X))
        # 処理の流れ自体は、_reclustering関数と同様
        # データ数でループ
        for i in range(len(X)):
            # 比較のための初期値
            dist_m = 10**20
            # クラスタ数でループ
            for j in range(self.record_cluster):
                # 該当クラスタの中心点との距離を計算
                xxxxxxxxxxxxxxxxxxxxxxxxxxxxx
                # 前回保存した（あるいは初期値）より距離が小さければ、そちらのクラスタを採用
                if dist < dist_m:
                    dist_m = dist
                    y_pred[i] = j
        return y_pred

# %% [markdown]
# # 事前準備：データ作成

# %%
# Simple Data Set 3
from sklearn.datasets import make_blobs

X, _ = make_blobs(n_samples=100,
                  n_features=2,
                  centers=4,
                  cluster_std=0.5,
                  shuffle=True,
                  random_state=0)

# %%
# Data Distribution Visualization
fig = plt.subplots(figsize=(12,8))
plt.rcParams["font.size"] = 20
plt.scatter(X[:,0],X[:,1],s=80);

# %%
from sklearn.model_selection import train_test_split
X_train, X_valid = \
train_test_split(X,train_size=0.8,random_state=None)

print(X_train.shape)
print(X_valid.shape)
# Out:
# (80, 2)
# (20, 2)

# %% [markdown]
# # 問題1
#
# スクラッチコード86行目
#
# `self.myu = X[np.random.choice(len(X),size=self.n_clusters,replace=False)]`

# %% [markdown]
# # 問題2
#
# 53行目：`def calc_sse(self,X)`

# %% [markdown]
# # 問題3
#
# 34行目：`def _update_cluster(self,X)`

# %% [markdown]
# # 問題4
#
# 22行目：`def _update_myu(self,X)`

# %% [markdown]
# # 問題5
#
# 83行目：`for i in range(self.n_init):`
#
# 93行目：`for j in range(self.n_iter):`

# %% [markdown]
# # 問題6

# %%
clf = ScratchKMeans(n_clusters=4,n_init=5,n_iter=100,verbose=True)
clf.fit(X_train)
# Out:
# 初期化：0　学習回数：0　最善のSSE：2475.1605687271267
# 初期化：0　学習回数：1　最善のSSE：228.11568968722423
# 初期化：0　学習回数：2　最善のSSE：113.70168380679243
# 初期化：0　学習回数：3　最善のSSE：68.05588104039008
# 初期化：0　学習回数：4　最善のSSE：41.804352548471
# 初期化：0　学習回数：5　最善のSSE：40.01458256380636
# 初期化：0　学習回数：6　最善のSSE：40.01458256380636
# 初期化：0　学習回数：7　最善のSSE：40.01458256380636
# 初期化：0　学習回数：8　最善のSSE：40.01458256380636
# 初期化：0　学習回数：9　最善のSSE：40.01458256380636
# 初期化：0　学習回数：10　最善のSSE：40.01458256380636
# 初期化：0　学習回数：11　最善のSSE：40.01458256380636
# 初期化：0　学習回数：12　最善のSSE：40.01458256380636
# 初期化：0　学習回数：13　最善のSSE：40.01458256380636
# 初期化：0　学習回数：14　最善のSSE：40.01458256380636
# 初期化：0　学習回数：15　最善のSSE：40.01458256380636
# 初期化：0　学習回数：16　最善のSSE：40.01458256380636
# 初期化：0　学習回数：17　最善のSSE：40.01458256380636
# 初期化：0　学習回数：18　最善のSSE：40.01458256380636
# 初期化：0　学習回数：19　最善のSSE：40.01458256380636
# 初期化：0　学習回数：20　最善のSSE：40.01458256380636
# 初期化：0　学習回数：21　最善のSSE：40.01458256380636
# 初期化：0　学習回数：22　最善のSSE：40.01458256380636
# 初期化：0　学習回数：23　最善のSSE：40.01458256380636
# 初期化：0　学習回数：24　最善のSSE：40.01458256380636
# 初期化：0　学習回数：25　最善のSSE：40.01458256380636
# 初期化：0　学習回数：26　最善のSSE：40.01458256380636
# 初期化：0　学習回数：27　最善のSSE：40.01458256380636
# 初期化：0　学習回数：28　最善のSSE：40.01458256380636
# 初期化：0　学習回数：29　最善のSSE：40.01458256380636
# 初期化：0　学習回数：30　最善のSSE：40.01458256380636
# 初期化：0　学習回数：31　最善のSSE：40.01458256380636
# 初期化：0　学習回数：32　最善のSSE：40.01458256380636
# 初期化：0　学習回数：33　最善のSSE：40.01458256380636
# 初期化：0　学習回数：34　最善のSSE：40.01458256380636
# 初期化：0　学習回数：35　最善のSSE：40.01458256380636
# 初期化：0　学習回数：36　最善のSSE：40.01458256380636
# 初期化：0　学習回数：37　最善のSSE：40.01458256380636
# 初期化：0　学習回数：38　最善のSSE：40.01458256380636
# 初期化：0　学習回数：39　最善のSSE：40.01458256380636
# 初期化：0　学習回数：40　最善のSSE：40.01458256380636
# 初期化：0　学習回数：41　最善のSSE：40.01458256380636
# 初期化：0　学習回数：42　最善のSSE：40.01458256380636
# 初期化：0　学習回数：43　最善のSSE：40.01458256380636
# 初期化：0　学習回数：44　最善のSSE：40.01458256380636
# 初期化：0　学習回数：45　最善のSSE：40.01458256380636
# 初期化：0　学習回数：46　最善のSSE：40.01458256380636
# 初期化：0　学習回数：47　最善のSSE：40.01458256380636
# 初期化：0　学習回数：48　最善のSSE：40.01458256380636
# 初期化：0　学習回数：49　最善のSSE：40.01458256380636
# 初期化：0　学習回数：50　最善のSSE：40.01458256380636
# 初期化：0　学習回数：51　最善のSSE：40.01458256380636
# 初期化：0　学習回数：52　最善のSSE：40.01458256380636
# 初期化：0　学習回数：53　最善のSSE：40.01458256380636
# 初期化：0　学習回数：54　最善のSSE：40.01458256380636
# 初期化：0　学習回数：55　最善のSSE：40.01458256380636
# 初期化：0　学習回数：56　最善のSSE：40.01458256380636
# 初期化：0　学習回数：57　最善のSSE：40.01458256380636
# 初期化：0　学習回数：58　最善のSSE：40.01458256380636
# 初期化：0　学習回数：59　最善のSSE：40.01458256380636
# 初期化：0　学習回数：60　最善のSSE：40.01458256380636
# 初期化：0　学習回数：61　最善のSSE：40.01458256380636
# 初期化：0　学習回数：62　最善のSSE：40.01458256380636
# 初期化：0　学習回数：63　最善のSSE：40.01458256380636
# 初期化：0　学習回数：64　最善のSSE：40.01458256380636
# 初期化：0　学習回数：65　最善のSSE：40.01458256380636
# 初期化：0　学習回数：66　最善のSSE：40.01458256380636
# 初期化：0　学習回数：67　最善のSSE：40.01458256380636
# 初期化：0　学習回数：68　最善のSSE：40.01458256380636
# 初期化：0　学習回数：69　最善のSSE：40.01458256380636
# 初期化：0　学習回数：70　最善のSSE：40.01458256380636
# 初期化：0　学習回数：71　最善のSSE：40.01458256380636
# 初期化：0　学習回数：72　最善のSSE：40.01458256380636
# 初期化：0　学習回数：73　最善のSSE：40.01458256380636
# 初期化：0　学習回数：74　最善のSSE：40.01458256380636
# 初期化：0　学習回数：75　最善のSSE：40.01458256380636
# 初期化：0　学習回数：76　最善のSSE：40.01458256380636
# 初期化：0　学習回数：77　最善のSSE：40.01458256380636
# 初期化：0　学習回数：78　最善のSSE：40.01458256380636
# 初期化：0　学習回数：79　最善のSSE：40.01458256380636
# 初期化：0　学習回数：80　最善のSSE：40.01458256380636
# 初期化：0　学習回数：81　最善のSSE：40.01458256380636
# 初期化：0　学習回数：82　最善のSSE：40.01458256380636
# 初期化：0　学習回数：83　最善のSSE：40.01458256380636
# 初期化：0　学習回数：84　最善のSSE：40.01458256380636
# 初期化：0　学習回数：85　最善のSSE：40.01458256380636
# 初期化：0　学習回数：86　最善のSSE：40.01458256380636
# 初期化：0　学習回数：87　最善のSSE：40.01458256380636
# 初期化：0　学習回数：88　最善のSSE：40.01458256380636
# 初期化：0　学習回数：89　最善のSSE：40.01458256380636
# 初期化：0　学習回数：90　最善のSSE：40.01458256380636
# 初期化：0　学習回数：91　最善のSSE：40.01458256380636
# 初期化：0　学習回数：92　最善のSSE：40.01458256380636
# 初期化：0　学習回数：93　最善のSSE：40.01458256380636
# 初期化：0　学習回数：94　最善のSSE：40.01458256380636
# 初期化：0　学習回数：95　最善のSSE：40.01458256380636
# 初期化：0　学習回数：96　最善のSSE：40.01458256380636
# 初期化：0　学習回数：97　最善のSSE：40.01458256380636
# 初期化：0　学習回数：98　最善のSSE：40.01458256380636
# 初期化：0　学習回数：99　最善のSSE：40.01458256380636
# 初期化：1　学習回数：0　最善のSSE：40.01458256380636
# 初期化：1　学習回数：1　最善のSSE：40.01458256380636
# 初期化：1　学習回数：2　最善のSSE：40.01458256380636
# 初期化：1　学習回数：3　最善のSSE：40.01458256380636
# 初期化：1　学習回数：4　最善のSSE：40.01458256380636
# 初期化：1　学習回数：5　最善のSSE：40.01458256380636
# 初期化：1　学習回数：6　最善のSSE：40.01458256380636
# 初期化：1　学習回数：7　最善のSSE：40.01458256380636
# 初期化：1　学習回数：8　最善のSSE：40.01458256380636
# 初期化：1　学習回数：9　最善のSSE：40.01458256380636
# 初期化：1　学習回数：10　最善のSSE：40.01458256380636
# 初期化：1　学習回数：11　最善のSSE：40.01458256380636
# 初期化：1　学習回数：12　最善のSSE：40.01458256380636
# 初期化：1　学習回数：13　最善のSSE：40.01458256380636
# 初期化：1　学習回数：14　最善のSSE：40.01458256380636
# 初期化：1　学習回数：15　最善のSSE：40.01458256380636
# 初期化：1　学習回数：16　最善のSSE：40.01458256380636
# 初期化：1　学習回数：17　最善のSSE：40.01458256380636
# 初期化：1　学習回数：18　最善のSSE：40.01458256380636
# 初期化：1　学習回数：19　最善のSSE：40.01458256380636
# 初期化：1　学習回数：20　最善のSSE：40.01458256380636
# 初期化：1　学習回数：21　最善のSSE：40.01458256380636
# 初期化：1　学習回数：22　最善のSSE：40.01458256380636
# 初期化：1　学習回数：23　最善のSSE：40.01458256380636
# 初期化：1　学習回数：24　最善のSSE：40.01458256380636
# 初期化：1　学習回数：25　最善のSSE：40.01458256380636
# 初期化：1　学習回数：26　最善のSSE：40.01458256380636
# 初期化：1　学習回数：27　最善のSSE：40.01458256380636
# 初期化：1　学習回数：28　最善のSSE：40.01458256380636
# 初期化：1　学習回数：29　最善のSSE：40.01458256380636
# 初期化：1　学習回数：30　最善のSSE：40.01458256380636
# 初期化：1　学習回数：31　最善のSSE：40.01458256380636
# 初期化：1　学習回数：32　最善のSSE：40.01458256380636
# 初期化：1　学習回数：33　最善のSSE：40.01458256380636
# 初期化：1　学習回数：34　最善のSSE：40.01458256380636
# 初期化：1　学習回数：35　最善のSSE：40.01458256380636
# 初期化：1　学習回数：36　最善のSSE：40.01458256380636
# 初期化：1　学習回数：37　最善のSSE：40.01458256380636
# 初期化：1　学習回数：38　最善のSSE：40.01458256380636
# 初期化：1　学習回数：39　最善のSSE：40.01458256380636
# 初期化：1　学習回数：40　最善のSSE：40.01458256380636
# 初期化：1　学習回数：41　最善のSSE：40.01458256380636
# 初期化：1　学習回数：42　最善のSSE：40.01458256380636
# 初期化：1　学習回数：43　最善のSSE：40.01458256380636
# 初期化：1　学習回数：44　最善のSSE：40.01458256380636
# 初期化：1　学習回数：45　最善のSSE：40.01458256380636
# 初期化：1　学習回数：46　最善のSSE：40.01458256380636
# 初期化：1　学習回数：47　最善のSSE：40.01458256380636
# 初期化：1　学習回数：48　最善のSSE：40.01458256380636
# 初期化：1　学習回数：49　最善のSSE：40.01458256380636
# 初期化：1　学習回数：50　最善のSSE：40.01458256380636
# 初期化：1　学習回数：51　最善のSSE：40.01458256380636
# 初期化：1　学習回数：52　最善のSSE：40.01458256380636
# 初期化：1　学習回数：53　最善のSSE：40.01458256380636
# 初期化：1　学習回数：54　最善のSSE：40.01458256380636
# 初期化：1　学習回数：55　最善のSSE：40.01458256380636
# 初期化：1　学習回数：56　最善のSSE：40.01458256380636
# 初期化：1　学習回数：57　最善のSSE：40.01458256380636
# 初期化：1　学習回数：58　最善のSSE：40.01458256380636
# 初期化：1　学習回数：59　最善のSSE：40.01458256380636
# 初期化：1　学習回数：60　最善のSSE：40.01458256380636
# 初期化：1　学習回数：61　最善のSSE：40.01458256380636
# 初期化：1　学習回数：62　最善のSSE：40.01458256380636
# 初期化：1　学習回数：63　最善のSSE：40.01458256380636
# 初期化：1　学習回数：64　最善のSSE：40.01458256380636
# 初期化：1　学習回数：65　最善のSSE：40.01458256380636
# 初期化：1　学習回数：66　最善のSSE：40.01458256380636
# 初期化：1　学習回数：67　最善のSSE：40.01458256380636
# 初期化：1　学習回数：68　最善のSSE：40.01458256380636
# 初期化：1　学習回数：69　最善のSSE：40.01458256380636
# 初期化：1　学習回数：70　最善のSSE：40.01458256380636
# 初期化：1　学習回数：71　最善のSSE：40.01458256380636
# 初期化：1　学習回数：72　最善のSSE：40.01458256380636
# 初期化：1　学習回数：73　最善のSSE：40.01458256380636
# 初期化：1　学習回数：74　最善のSSE：40.01458256380636
# 初期化：1　学習回数：75　最善のSSE：40.01458256380636
# 初期化：1　学習回数：76　最善のSSE：40.01458256380636
# 初期化：1　学習回数：77　最善のSSE：40.01458256380636
# 初期化：1　学習回数：78　最善のSSE：40.01458256380636
# 初期化：1　学習回数：79　最善のSSE：40.01458256380636
# 初期化：1　学習回数：80　最善のSSE：40.01458256380636
# 初期化：1　学習回数：81　最善のSSE：40.01458256380636
# 初期化：1　学習回数：82　最善のSSE：40.01458256380636
# 初期化：1　学習回数：83　最善のSSE：40.01458256380636
# 初期化：1　学習回数：84　最善のSSE：40.01458256380636
# 初期化：1　学習回数：85　最善のSSE：40.01458256380636
# 初期化：1　学習回数：86　最善のSSE：40.01458256380636
# 初期化：1　学習回数：87　最善のSSE：40.01458256380636
# 初期化：1　学習回数：88　最善のSSE：40.01458256380636
# 初期化：1　学習回数：89　最善のSSE：40.01458256380636
# 初期化：1　学習回数：90　最善のSSE：40.01458256380636
# 初期化：1　学習回数：91　最善のSSE：40.01458256380636
# 初期化：1　学習回数：92　最善のSSE：40.01458256380636
# 初期化：1　学習回数：93　最善のSSE：40.01458256380636
# 初期化：1　学習回数：94　最善のSSE：40.01458256380636
# 初期化：1　学習回数：95　最善のSSE：40.01458256380636
# 初期化：1　学習回数：96　最善のSSE：40.01458256380636
# 初期化：1　学習回数：97　最善のSSE：40.01458256380636
# 初期化：1　学習回数：98　最善のSSE：40.01458256380636
# 初期化：1　学習回数：99　最善のSSE：40.01458256380636
# 初期化：2　学習回数：0　最善のSSE：40.01458256380636
# 初期化：2　学習回数：1　最善のSSE：40.01458256380636
# 初期化：2　学習回数：2　最善のSSE：40.01458256380636
# 初期化：2　学習回数：3　最善のSSE：40.01458256380636
# 初期化：2　学習回数：4　最善のSSE：40.01458256380636
# 初期化：2　学習回数：5　最善のSSE：40.01458256380636
# 初期化：2　学習回数：6　最善のSSE：40.01458256380636
# 初期化：2　学習回数：7　最善のSSE：40.01458256380636
# 初期化：2　学習回数：8　最善のSSE：40.01458256380636
# 初期化：2　学習回数：9　最善のSSE：40.01458256380636
# 初期化：2　学習回数：10　最善のSSE：40.01458256380636
# 初期化：2　学習回数：11　最善のSSE：40.01458256380636
# 初期化：2　学習回数：12　最善のSSE：40.01458256380636
# 初期化：2　学習回数：13　最善のSSE：40.01458256380636
# 初期化：2　学習回数：14　最善のSSE：40.01458256380636
# 初期化：2　学習回数：15　最善のSSE：40.01458256380636
# 初期化：2　学習回数：16　最善のSSE：40.01458256380636
# 初期化：2　学習回数：17　最善のSSE：40.01458256380636
# 初期化：2　学習回数：18　最善のSSE：40.01458256380636
# 初期化：2　学習回数：19　最善のSSE：40.01458256380636
# 初期化：2　学習回数：20　最善のSSE：40.01458256380636
# 初期化：2　学習回数：21　最善のSSE：40.01458256380636
# 初期化：2　学習回数：22　最善のSSE：40.01458256380636
# 初期化：2　学習回数：23　最善のSSE：40.01458256380636
# 初期化：2　学習回数：24　最善のSSE：40.01458256380636
# 初期化：2　学習回数：25　最善のSSE：40.01458256380636
# 初期化：2　学習回数：26　最善のSSE：40.01458256380636
# 初期化：2　学習回数：27　最善のSSE：40.01458256380636
# 初期化：2　学習回数：28　最善のSSE：40.01458256380636
# 初期化：2　学習回数：29　最善のSSE：40.01458256380636
# 初期化：2　学習回数：30　最善のSSE：40.01458256380636
# 初期化：2　学習回数：31　最善のSSE：40.01458256380636
# 初期化：2　学習回数：32　最善のSSE：40.01458256380636
# 初期化：2　学習回数：33　最善のSSE：40.01458256380636
# 初期化：2　学習回数：34　最善のSSE：40.01458256380636
# 初期化：2　学習回数：35　最善のSSE：40.01458256380636
# 初期化：2　学習回数：36　最善のSSE：40.01458256380636
# 初期化：2　学習回数：37　最善のSSE：40.01458256380636
# 初期化：2　学習回数：38　最善のSSE：40.01458256380636
# 初期化：2　学習回数：39　最善のSSE：40.01458256380636
# 初期化：2　学習回数：40　最善のSSE：40.01458256380636
# 初期化：2　学習回数：41　最善のSSE：40.01458256380636
# 初期化：2　学習回数：42　最善のSSE：40.01458256380636
# 初期化：2　学習回数：43　最善のSSE：40.01458256380636
# 初期化：2　学習回数：44　最善のSSE：40.01458256380636
# 初期化：2　学習回数：45　最善のSSE：40.01458256380636
# 初期化：2　学習回数：46　最善のSSE：40.01458256380636
# 初期化：2　学習回数：47　最善のSSE：40.01458256380636
# 初期化：2　学習回数：48　最善のSSE：40.01458256380636
# 初期化：2　学習回数：49　最善のSSE：40.01458256380636
# 初期化：2　学習回数：50　最善のSSE：40.01458256380636
# 初期化：2　学習回数：51　最善のSSE：40.01458256380636
# 初期化：2　学習回数：52　最善のSSE：40.01458256380636
# 初期化：2　学習回数：53　最善のSSE：40.01458256380636
# 初期化：2　学習回数：54　最善のSSE：40.01458256380636
# 初期化：2　学習回数：55　最善のSSE：40.01458256380636
# 初期化：2　学習回数：56　最善のSSE：40.01458256380636
# 初期化：2　学習回数：57　最善のSSE：40.01458256380636
# 初期化：2　学習回数：58　最善のSSE：40.01458256380636
# 初期化：2　学習回数：59　最善のSSE：40.01458256380636
# 初期化：2　学習回数：60　最善のSSE：40.01458256380636
# 初期化：2　学習回数：61　最善のSSE：40.01458256380636
# 初期化：2　学習回数：62　最善のSSE：40.01458256380636
# 初期化：2　学習回数：63　最善のSSE：40.01458256380636
# 初期化：2　学習回数：64　最善のSSE：40.01458256380636
# 初期化：2　学習回数：65　最善のSSE：40.01458256380636
# 初期化：2　学習回数：66　最善のSSE：40.01458256380636
# 初期化：2　学習回数：67　最善のSSE：40.01458256380636
# 初期化：2　学習回数：68　最善のSSE：40.01458256380636
# 初期化：2　学習回数：69　最善のSSE：40.01458256380636
# 初期化：2　学習回数：70　最善のSSE：40.01458256380636
# 初期化：2　学習回数：71　最善のSSE：40.01458256380636
# 初期化：2　学習回数：72　最善のSSE：40.01458256380636
# 初期化：2　学習回数：73　最善のSSE：40.01458256380636
# 初期化：2　学習回数：74　最善のSSE：40.01458256380636
# 初期化：2　学習回数：75　最善のSSE：40.01458256380636
# 初期化：2　学習回数：76　最善のSSE：40.01458256380636
# 初期化：2　学習回数：77　最善のSSE：40.01458256380636
# 初期化：2　学習回数：78　最善のSSE：40.01458256380636
# 初期化：2　学習回数：79　最善のSSE：40.01458256380636
# 初期化：2　学習回数：80　最善のSSE：40.01458256380636
# 初期化：2　学習回数：81　最善のSSE：40.01458256380636
# 初期化：2　学習回数：82　最善のSSE：40.01458256380636
# 初期化：2　学習回数：83　最善のSSE：40.01458256380636
# 初期化：2　学習回数：84　最善のSSE：40.01458256380636
# 初期化：2　学習回数：85　最善のSSE：40.01458256380636
# 初期化：2　学習回数：86　最善のSSE：40.01458256380636
# 初期化：2　学習回数：87　最善のSSE：40.01458256380636
# 初期化：2　学習回数：88　最善のSSE：40.01458256380636
# 初期化：2　学習回数：89　最善のSSE：40.01458256380636
# 初期化：2　学習回数：90　最善のSSE：40.01458256380636
# 初期化：2　学習回数：91　最善のSSE：40.01458256380636
# 初期化：2　学習回数：92　最善のSSE：40.01458256380636
# 初期化：2　学習回数：93　最善のSSE：40.01458256380636
# 初期化：2　学習回数：94　最善のSSE：40.01458256380636
# 初期化：2　学習回数：95　最善のSSE：40.01458256380636
# 初期化：2　学習回数：96　最善のSSE：40.01458256380636
# 初期化：2　学習回数：97　最善のSSE：40.01458256380636
# 初期化：2　学習回数：98　最善のSSE：40.01458256380636
# 初期化：2　学習回数：99　最善のSSE：40.01458256380636
# 初期化：3　学習回数：0　最善のSSE：40.01458256380636
# 初期化：3　学習回数：1　最善のSSE：40.01458256380636
# 初期化：3　学習回数：2　最善のSSE：40.01458256380636
# 初期化：3　学習回数：3　最善のSSE：40.01458256380636
# 初期化：3　学習回数：4　最善のSSE：40.01458256380636
# 初期化：3　学習回数：5　最善のSSE：40.01458256380636
# 初期化：3　学習回数：6　最善のSSE：40.01458256380636
# 初期化：3　学習回数：7　最善のSSE：40.01458256380636
# 初期化：3　学習回数：8　最善のSSE：40.01458256380636
# 初期化：3　学習回数：9　最善のSSE：40.01458256380636
# 初期化：3　学習回数：10　最善のSSE：40.01458256380636
# 初期化：3　学習回数：11　最善のSSE：40.01458256380636
# 初期化：3　学習回数：12　最善のSSE：40.01458256380636
# 初期化：3　学習回数：13　最善のSSE：40.01458256380636
# 初期化：3　学習回数：14　最善のSSE：40.01458256380636
# 初期化：3　学習回数：15　最善のSSE：40.01458256380636
# 初期化：3　学習回数：16　最善のSSE：40.01458256380636
# 初期化：3　学習回数：17　最善のSSE：40.01458256380636
# 初期化：3　学習回数：18　最善のSSE：40.01458256380636
# 初期化：3　学習回数：19　最善のSSE：40.01458256380636
# 初期化：3　学習回数：20　最善のSSE：40.01458256380636
# 初期化：3　学習回数：21　最善のSSE：40.01458256380636
# 初期化：3　学習回数：22　最善のSSE：40.01458256380636
# 初期化：3　学習回数：23　最善のSSE：40.01458256380636
# 初期化：3　学習回数：24　最善のSSE：40.01458256380636
# 初期化：3　学習回数：25　最善のSSE：40.01458256380636
# 初期化：3　学習回数：26　最善のSSE：40.01458256380636
# 初期化：3　学習回数：27　最善のSSE：40.01458256380636
# 初期化：3　学習回数：28　最善のSSE：40.01458256380636
# 初期化：3　学習回数：29　最善のSSE：40.01458256380636
# 初期化：3　学習回数：30　最善のSSE：40.01458256380636
# 初期化：3　学習回数：31　最善のSSE：40.01458256380636
# 初期化：3　学習回数：32　最善のSSE：40.01458256380636
# 初期化：3　学習回数：33　最善のSSE：40.01458256380636
# 初期化：3　学習回数：34　最善のSSE：40.01458256380636
# 初期化：3　学習回数：35　最善のSSE：40.01458256380636
# 初期化：3　学習回数：36　最善のSSE：40.01458256380636
# 初期化：3　学習回数：37　最善のSSE：40.01458256380636
# 初期化：3　学習回数：38　最善のSSE：40.01458256380636
# 初期化：3　学習回数：39　最善のSSE：40.01458256380636
# 初期化：3　学習回数：40　最善のSSE：40.01458256380636
# 初期化：3　学習回数：41　最善のSSE：40.01458256380636
# 初期化：3　学習回数：42　最善のSSE：40.01458256380636
# 初期化：3　学習回数：43　最善のSSE：40.01458256380636
# 初期化：3　学習回数：44　最善のSSE：40.01458256380636
# 初期化：3　学習回数：45　最善のSSE：40.01458256380636
# 初期化：3　学習回数：46　最善のSSE：40.01458256380636
# 初期化：3　学習回数：47　最善のSSE：40.01458256380636
# 初期化：3　学習回数：48　最善のSSE：40.01458256380636
# 初期化：3　学習回数：49　最善のSSE：40.01458256380636
# 初期化：3　学習回数：50　最善のSSE：40.01458256380636
# 初期化：3　学習回数：51　最善のSSE：40.01458256380636
# 初期化：3　学習回数：52　最善のSSE：40.01458256380636
# 初期化：3　学習回数：53　最善のSSE：40.01458256380636
# 初期化：3　学習回数：54　最善のSSE：40.01458256380636
# 初期化：3　学習回数：55　最善のSSE：40.01458256380636
# 初期化：3　学習回数：56　最善のSSE：40.01458256380636
# 初期化：3　学習回数：57　最善のSSE：40.01458256380636
# 初期化：3　学習回数：58　最善のSSE：40.01458256380636
# 初期化：3　学習回数：59　最善のSSE：40.01458256380636
# 初期化：3　学習回数：60　最善のSSE：40.01458256380636
# 初期化：3　学習回数：61　最善のSSE：40.01458256380636
# 初期化：3　学習回数：62　最善のSSE：40.01458256380636
# 初期化：3　学習回数：63　最善のSSE：40.01458256380636
# 初期化：3　学習回数：64　最善のSSE：40.01458256380636
# 初期化：3　学習回数：65　最善のSSE：40.01458256380636
# 初期化：3　学習回数：66　最善のSSE：40.01458256380636
# 初期化：3　学習回数：67　最善のSSE：40.01458256380636
# 初期化：3　学習回数：68　最善のSSE：40.01458256380636
# 初期化：3　学習回数：69　最善のSSE：40.01458256380636
# 初期化：3　学習回数：70　最善のSSE：40.01458256380636
# 初期化：3　学習回数：71　最善のSSE：40.01458256380636
# 初期化：3　学習回数：72　最善のSSE：40.01458256380636
# 初期化：3　学習回数：73　最善のSSE：40.01458256380636
# 初期化：3　学習回数：74　最善のSSE：40.01458256380636
# 初期化：3　学習回数：75　最善のSSE：40.01458256380636
# 初期化：3　学習回数：76　最善のSSE：40.01458256380636
# 初期化：3　学習回数：77　最善のSSE：40.01458256380636
# 初期化：3　学習回数：78　最善のSSE：40.01458256380636
# 初期化：3　学習回数：79　最善のSSE：40.01458256380636
# 初期化：3　学習回数：80　最善のSSE：40.01458256380636
# 初期化：3　学習回数：81　最善のSSE：40.01458256380636
# 初期化：3　学習回数：82　最善のSSE：40.01458256380636
# 初期化：3　学習回数：83　最善のSSE：40.01458256380636
# 初期化：3　学習回数：84　最善のSSE：40.01458256380636
# 初期化：3　学習回数：85　最善のSSE：40.01458256380636
# 初期化：3　学習回数：86　最善のSSE：40.01458256380636
# 初期化：3　学習回数：87　最善のSSE：40.01458256380636
# 初期化：3　学習回数：88　最善のSSE：40.01458256380636
# 初期化：3　学習回数：89　最善のSSE：40.01458256380636
# 初期化：3　学習回数：90　最善のSSE：40.01458256380636
# 初期化：3　学習回数：91　最善のSSE：40.01458256380636
# 初期化：3　学習回数：92　最善のSSE：40.01458256380636
# 初期化：3　学習回数：93　最善のSSE：40.01458256380636
# 初期化：3　学習回数：94　最善のSSE：40.01458256380636
# 初期化：3　学習回数：95　最善のSSE：40.01458256380636
# 初期化：3　学習回数：96　最善のSSE：40.01458256380636
# 初期化：3　学習回数：97　最善のSSE：40.01458256380636
# 初期化：3　学習回数：98　最善のSSE：40.01458256380636
# 初期化：3　学習回数：99　最善のSSE：40.01458256380636
# 初期化：4　学習回数：0　最善のSSE：40.01458256380636
# 初期化：4　学習回数：1　最善のSSE：40.01458256380636
# 初期化：4　学習回数：2　最善のSSE：40.01458256380636
# 初期化：4　学習回数：3　最善のSSE：40.01458256380636
# 初期化：4　学習回数：4　最善のSSE：40.01458256380636
# 初期化：4　学習回数：5　最善のSSE：40.01458256380636
# 初期化：4　学習回数：6　最善のSSE：40.01458256380636
# 初期化：4　学習回数：7　最善のSSE：40.01458256380636
# 初期化：4　学習回数：8　最善のSSE：40.01458256380636
# 初期化：4　学習回数：9　最善のSSE：40.01458256380636
# 初期化：4　学習回数：10　最善のSSE：40.01458256380636
# 初期化：4　学習回数：11　最善のSSE：40.01458256380636
# 初期化：4　学習回数：12　最善のSSE：40.01458256380636
# 初期化：4　学習回数：13　最善のSSE：40.01458256380636
# 初期化：4　学習回数：14　最善のSSE：40.01458256380636
# 初期化：4　学習回数：15　最善のSSE：40.01458256380636
# 初期化：4　学習回数：16　最善のSSE：40.01458256380636
# 初期化：4　学習回数：17　最善のSSE：40.01458256380636
# 初期化：4　学習回数：18　最善のSSE：40.01458256380636
# 初期化：4　学習回数：19　最善のSSE：40.01458256380636
# 初期化：4　学習回数：20　最善のSSE：40.01458256380636
# 初期化：4　学習回数：21　最善のSSE：40.01458256380636
# 初期化：4　学習回数：22　最善のSSE：40.01458256380636
# 初期化：4　学習回数：23　最善のSSE：40.01458256380636
# 初期化：4　学習回数：24　最善のSSE：40.01458256380636
# 初期化：4　学習回数：25　最善のSSE：40.01458256380636
# 初期化：4　学習回数：26　最善のSSE：40.01458256380636
# 初期化：4　学習回数：27　最善のSSE：40.01458256380636
# 初期化：4　学習回数：28　最善のSSE：40.01458256380636
# 初期化：4　学習回数：29　最善のSSE：40.01458256380636
# 初期化：4　学習回数：30　最善のSSE：40.01458256380636
# 初期化：4　学習回数：31　最善のSSE：40.01458256380636
# 初期化：4　学習回数：32　最善のSSE：40.01458256380636
# 初期化：4　学習回数：33　最善のSSE：40.01458256380636
# 初期化：4　学習回数：34　最善のSSE：40.01458256380636
# 初期化：4　学習回数：35　最善のSSE：40.01458256380636
# 初期化：4　学習回数：36　最善のSSE：40.01458256380636
# 初期化：4　学習回数：37　最善のSSE：40.01458256380636
# 初期化：4　学習回数：38　最善のSSE：40.01458256380636
# 初期化：4　学習回数：39　最善のSSE：40.01458256380636
# 初期化：4　学習回数：40　最善のSSE：40.01458256380636
# 初期化：4　学習回数：41　最善のSSE：40.01458256380636
# 初期化：4　学習回数：42　最善のSSE：40.01458256380636
# 初期化：4　学習回数：43　最善のSSE：40.01458256380636
# 初期化：4　学習回数：44　最善のSSE：40.01458256380636
# 初期化：4　学習回数：45　最善のSSE：40.01458256380636
# 初期化：4　学習回数：46　最善のSSE：40.01458256380636
# 初期化：4　学習回数：47　最善のSSE：40.01458256380636
# 初期化：4　学習回数：48　最善のSSE：40.01458256380636
# 初期化：4　学習回数：49　最善のSSE：40.01458256380636
# 初期化：4　学習回数：50　最善のSSE：40.01458256380636
# 初期化：4　学習回数：51　最善のSSE：40.01458256380636
# 初期化：4　学習回数：52　最善のSSE：40.01458256380636
# 初期化：4　学習回数：53　最善のSSE：40.01458256380636
# 初期化：4　学習回数：54　最善のSSE：40.01458256380636
# 初期化：4　学習回数：55　最善のSSE：40.01458256380636
# 初期化：4　学習回数：56　最善のSSE：40.01458256380636
# 初期化：4　学習回数：57　最善のSSE：40.01458256380636
# 初期化：4　学習回数：58　最善のSSE：40.01458256380636
# 初期化：4　学習回数：59　最善のSSE：40.01458256380636
# 初期化：4　学習回数：60　最善のSSE：40.01458256380636
# 初期化：4　学習回数：61　最善のSSE：40.01458256380636
# 初期化：4　学習回数：62　最善のSSE：40.01458256380636
# 初期化：4　学習回数：63　最善のSSE：40.01458256380636
# 初期化：4　学習回数：64　最善のSSE：40.01458256380636
# 初期化：4　学習回数：65　最善のSSE：40.01458256380636
# 初期化：4　学習回数：66　最善のSSE：40.01458256380636
# 初期化：4　学習回数：67　最善のSSE：40.01458256380636
# 初期化：4　学習回数：68　最善のSSE：40.01458256380636
# 初期化：4　学習回数：69　最善のSSE：40.01458256380636
# 初期化：4　学習回数：70　最善のSSE：40.01458256380636
# 初期化：4　学習回数：71　最善のSSE：40.01458256380636
# 初期化：4　学習回数：72　最善のSSE：40.01458256380636
# 初期化：4　学習回数：73　最善のSSE：40.01458256380636
# 初期化：4　学習回数：74　最善のSSE：40.01458256380636
# 初期化：4　学習回数：75　最善のSSE：40.01458256380636
# 初期化：4　学習回数：76　最善のSSE：40.01458256380636
# 初期化：4　学習回数：77　最善のSSE：40.01458256380636
# 初期化：4　学習回数：78　最善のSSE：40.01458256380636
# 初期化：4　学習回数：79　最善のSSE：40.01458256380636
# 初期化：4　学習回数：80　最善のSSE：40.01458256380636
# 初期化：4　学習回数：81　最善のSSE：40.01458256380636
# 初期化：4　学習回数：82　最善のSSE：40.01458256380636
# 初期化：4　学習回数：83　最善のSSE：40.01458256380636
# 初期化：4　学習回数：84　最善のSSE：40.01458256380636
# 初期化：4　学習回数：85　最善のSSE：40.01458256380636
# 初期化：4　学習回数：86　最善のSSE：40.01458256380636
# 初期化：4　学習回数：87　最善のSSE：40.01458256380636
# 初期化：4　学習回数：88　最善のSSE：40.01458256380636
# 初期化：4　学習回数：89　最善のSSE：40.01458256380636
# 初期化：4　学習回数：90　最善のSSE：40.01458256380636
# 初期化：4　学習回数：91　最善のSSE：40.01458256380636
# 初期化：4　学習回数：92　最善のSSE：40.01458256380636
# 初期化：4　学習回数：93　最善のSSE：40.01458256380636
# 初期化：4　学習回数：94　最善のSSE：40.01458256380636
# 初期化：4　学習回数：95　最善のSSE：40.01458256380636
# 初期化：4　学習回数：96　最善のSSE：40.01458256380636
# 初期化：4　学習回数：97　最善のSSE：40.01458256380636
# 初期化：4　学習回数：98　最善のSSE：40.01458256380636
# 初期化：4　学習回数：99　最善のSSE：40.01458256380636

# %% [markdown]
# # 問題7

# %%
pred = clf.predict(X_valid)
pred
# Out:
# array([0., 3., 1., 2., 2., 0., 1., 1., 1., 1., 0., 3., 0., 3., 3., 3., 3.,
#        1., 3., 1.])

# %% [markdown]
# # 問題8

# %%
elbow = {}
for k in range(1,8):
    model = ScratchKMeans(n_clusters=k,n_init=5,n_iter=100,verbose=False)
    model.fit(X)
    elbow[k] = model.best_sse

fig = plt.subplots(figsize=(12,8))
plt.rcParams["font.size"] = 20
plt.plot(list(elbow.keys()),list(elbow.values()),'rs--');

# %% [markdown]
# # 事前準備：データ作成＆PCA

# %%
# データ読み込み
data = pd.read_csv('Wholesale customers data.csv')
data
# Out:
#      Channel  Region  Fresh   Milk  Grocery  Frozen  Detergents_Paper  \
# 0          2       3  12669   9656     7561     214              2674
# 1          2       3   7057   9810     9568    1762              3293
# 2          2       3   6353   8808     7684    2405              3516
# 3          1       3  13265   1196     4221    6404               507
# 4          2       3  22615   5410     7198    3915              1777
# 5          2       3   9413   8259     5126     666              1795
# 6          2       3  12126   3199     6975     480              3140
# 7          2       3   7579   4956     9426    1669              3321
# 8          1       3   5963   3648     6192     425              1716
# 9          2       3   6006  11093    18881    1159              7425
# 10         2       3   3366   5403    12974    4400              5977
# 11         2       3  13146   1124     4523    1420               549
# 12         2       3  31714  12319    11757     287              3881
# 13         2       3  21217   6208    14982    3095              6707
# 14         2       3  24653   9465    12091     294              5058
# 15         1       3  10253   1114     3821     397               964
# 16         2       3   1020   8816    12121     134              4508
# 17         1       3   5876   6157     2933     839               370
# 18         2       3  18601   6327    10099    2205              2767
# 19         1       3   7780   2495     9464     669              2518
# 20         2       3  17546   4519     4602    1066              2259
# 21         1       3   5567    871     2010    3383               375
# 22         1       3  31276   1917     4469    9408              2381
# 23         2       3  26373  36423    22019    5154              4337
# 24         2       3  22647   9776    13792    2915              4482
# 25         2       3  16165   4230     7595     201              4003
# 26         1       3   9898    961     2861    3151               242
# 27         1       3  14276    803     3045     485               100
# 28         2       3   4113  20484    25957    1158              8604
# 29         1       3  43088   2100     2609    1200              1107
# ..       ...     ...    ...    ...      ...     ...               ...
# 410        1       3   6633   2096     4563    1389              1860
# 411        1       3   2126   3289     3281    1535               235
# 412        1       3     97   3605    12400      98              2970
# 413        1       3   4983   4859     6633   17866               912
# 414        1       3   5969   1990     3417    5679              1135
# 415        2       3   7842   6046     8552    1691              3540
# 416        2       3   4389  10940    10908     848              6728
# 417        1       3   5065   5499    11055     364              3485
# 418        2       3    660   8494    18622     133              6740
# 419        1       3   8861   3783     2223     633              1580
# 420        1       3   4456   5266    13227      25              6818
# 421        2       3  17063   4847     9053    1031              3415
# 422        1       3  26400   1377     4172     830               948
# 423        2       3  17565   3686     4657    1059              1803
# 424        2       3  16980   2884    12232     874              3213
# 425        1       3  11243   2408     2593   15348               108
# 426        1       3  13134   9347    14316    3141              5079
# 427        1       3  31012  16687     5429   15082               439
# 428        1       3   3047   5970     4910    2198               850
# 429        1       3   8607   1750     3580      47                84
# 430        1       3   3097   4230    16483     575               241
# 431        1       3   8533   5506     5160   13486              1377
# 432        1       3  21117   1162     4754     269              1328
# 433        1       3   1982   3218     1493    1541               356
# 434        1       3  16731   3922     7994     688              2371
# 435        1       3  29703  12051    16027   13135               182
# 436        1       3  39228   1431      764    4510                93
# 437        2       3  14531  15488    30243     437             14841
# 438        1       3  10290   1981     2232    1038               168
# 439        1       3   2787   1698     2510      65               477
#
#      Delicassen
# 0          1338
# 1          1776
# 2          7844
# 3          1788
# 4          5185
# 5          1451
# 6           545
# 7          2566
# 8           750
# 9          2098
# 10         1744
# 11          497
# 12         2931
# 13          602
# 14         2168
# 15          412
# 16         1080
# 17         4478
# 18         3181
# 19          501
# 20         2124
# 21          569
# 22         4334
# 23        16523
# 24         5778
# 25           57
# 26          833
# 27          518
# 28         5206
# 29          823
# ..          ...
# 410        1892
# 411        4365
# 412          62
# 413        2435
# 414         290
# 415        1874
# 416         993
# 417        1063
# 418         776
# 419        1521
# 420        1393
# 421        1784
# 422        1218
# 423         668
# 424         249
# 425        1886
# 426        1894
# 427        1163
# 428         317
# 429        2501
# 430        2080
# 431        1498
# 432         395
# 433        1449
# 434         838
# 435        2204
# 436        2346
# 437        1867
# 438        2125
# 439          52
#
# [440 rows x 8 columns]

# %%
# 主成分分析結果の可視化
# サンプルコードの実行
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
pca = PCA(n_components=None)
pca = pca.fit(data)
var_exp = pca.explained_variance_ratio_
cum_var_exp = np.cumsum(var_exp)
print(cum_var_exp)
plt.bar(range(1,9), var_exp, alpha=0.5, align='center')
plt.step(range(1,9), cum_var_exp, where='mid')
plt.ylabel('Explained variance ratio')
plt.xlabel('Principal components')
plt.hlines(0.7, 0, 6,  "blue", linestyles='dashed')
plt.legend(loc='best')
plt.grid()
plt.show()
# Out:
# No handles with labels found to put in legend.
# [0.45961362 0.86478588 0.93481596 0.97883941 0.99386152 1.
#  1.         1.        ]

# %% [markdown]
# # 問題10,11,12に関しては、考察系のため回答例の紹介は省略します。
#
#
# **卸売業者にとって有益な情報**を求めたいという目標があるため、それを前提に分析を行っていきます。
#
# **卸売業者にとって有益な情報**を次のように設定する
#
# 顧客をいくつかのクラスターに分け、そのクラスターの特性に合ったサービスを創出していきたい
#
# こういうビジネス的な施策を考える上での分析では、エルボー法やシルエット図のようないわゆる学問的なクラスタ数の決定方法より、ビジネスとしての実現可能性の方が重視されることが多い。
#
#
# + 任意のクラスタ数を決定(8つのクラスタに分けたところで、施策やサービスを8種類用意できると思わない)
# + クラスターに分ける
# + 各クラスターの傾向を見る
# + 施策を考える
# + 結果論的に施策が似ているクラスタは合体させる
